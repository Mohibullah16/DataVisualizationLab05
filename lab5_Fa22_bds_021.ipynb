# %%
import seaborn as sns

# Load the restaurant dataset
restaurant_data = sns.load_dataset('tips')
print(restaurant_data.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Question 1
# ## Distribution of Tips Across Different Days
# ### •	Visualize how tips are distributed across the different days of the week (day). Use box plots or violin plots to show the spread and central tendency of tip values.
# ### •	Is there a significant difference in the tip distribution between different days?

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(x='day', y='tip', data=restaurant_data, ax=axes[0])
axes[0].set_title('Distribution of Tips Across Different Days (Box Plot)')

sns.violinplot(x='day', y='tip', data=restaurant_data, ax=axes[1])
axes[1].set_title('Distribution of Tips Across Different Days (Violin Plot)')

plt.tight_layout()
plt.show()
